# %% [markdown]
# ### Exploratory Data Analysis

# %%
### Distbn, outliers, missing values, anomalies, identifying patterns, relationships

# %% [markdown]
# ### Distribution of a variable

# %% [markdown]
# ### Univariate --> one variable --> Measures of central tendency --> histogram, barchart, pie chart

# %% [markdown]
# ### Bivariate --> two --> relationship between variables --> scatterplot, pairplot

# %% [markdown]
# ### Multivariate--> more than two -->

# %%
### import the packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
## sns.set(style="whitegrid")
##sns.set(style="darkgrid")
##sns.set(style="dark")
sns.set(style="ticks")

# %%
df=pd.read_csv("Absenteeism_at_work.csv", sep=";")

# %%
##df.head(5)
df.head().style.background_gradient(cmap="Dark2")
# Out:
# <style type="text/css">
# #T_e5fbf_row0_col0, #T_e5fbf_row1_col6, #T_e5fbf_row2_col18, #T_e5fbf_row3_col7, #T_e5fbf_row4_col0 {
#   background-color: #d95f02;
#   color: #f1f1f1;
# }
# #T_e5fbf_row0_col1, #T_e5fbf_row0_col5, #T_e5fbf_row0_col13, #T_e5fbf_row0_col16, #T_e5fbf_row0_col20, #T_e5fbf_row1_col0, #T_e5fbf_row1_col7, #T_e5fbf_row1_col8, #T_e5fbf_row1_col11, #T_e5fbf_row1_col17, #T_e5fbf_row1_col18, #T_e5fbf_row1_col19, #T_e5fbf_row2_col1, #T_e5fbf_row2_col6, #T_e5fbf_row2_col7, #T_e5fbf_row2_col19, #T_e5fbf_row3_col3, #T_e5fbf_row3_col5, #T_e5fbf_row3_col13, #T_e5fbf_row3_col15, #T_e5fbf_row3_col20, #T_e5fbf_row4_col1, #T_e5fbf_row4_col3, #T_e5fbf_row4_col5, #T_e5fbf_row4_col13, #T_e5fbf_row4_col16 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
df.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
df["Reason for absence"].nunique()
# Out:
# 28

# %%
df["Reason for absence"].unique()
# Out:
# array([26,  0, 23,  7, 22, 19,  1, 11, 14, 21, 10, 13, 28, 18, 25, 24,  6,
#        27, 17,  8, 12,  5,  9, 15,  4,  3,  2, 16], dtype=int64)

# %%
df["Reason for absence"].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 21      6
# 8       6
# 9       4
# 5       3
# 16      3
# 24      3
# 15      2
# 4       2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
### Drop insignificant columns
df.drop("ID", axis=1, inplace=True)

# %%
df.describe(include="all")
## min value of month can't be zero
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
df["Month of absence"].value_counts()
# Out:
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64

# %%
df["Month of absence"].replace(0,1,inplace=True)

# %%
df.describe() ## Now min value for "" Month of absence" changed to 1
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.328378         3.914865    2.544595
# std              8.433406          3.429397         1.421675    1.111831
# min              0.000000          1.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
df.skew()
# Out:
# Reason for absence                -0.915312
# Month of absence                   0.076528
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# Body mass index                    0.305046
# Absenteeism time in hours          5.720728
# dtype: float64

# %%
sns.distplot(df["Absenteeism time in hours"])
plt.show()
## As the curve is on left handside or most of data is distributed on left hand side, it is positively skewed

# %%
df["Seasons"].value_counts()
# Out:
# 4    195
# 2    192
# 3    183
# 1    170
# Name: Seasons, dtype: int64

# %%
df["Seasons"].value_counts().plot(kind="bar")
plt.title("Absence in Different Seasons")
plt.xlabel("Seasons")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Conclusion for above 4--> Spring--> More absentees in Spring

# %%
df["Education"].value_counts().plot(kind="bar")
plt.title("Absence in Different Seasons")
plt.xlabel("Education")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Conclusion for above --> 1 is more (More absentees from High school)

# %%
df["Social drinker"].value_counts().plot(kind="bar")
plt.title("Absence in Different Seasons")
plt.xlabel("Social Drinker")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Conclusion for above --> 1 --> Social drinker more abseence

# %%
df["Social smoker"].value_counts().plot(kind="bar")
plt.title("Absence in Different Seasons")
plt.xlabel("Social smoker")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Conclusion for above --> 0 --> Not a Social smoker more abseence

# %%
### Bivariate analysis
corr=df.corr()
corr
# Out:
#                                  Reason for absence  Month of absence  \
# Reason for absence                         1.000000         -0.086724
# Month of absence                          -0.086724          1.000000
# Day of the week                            0.116319         -0.006193
# Seasons                                   -0.117925          0.408009
# Transportation expense                    -0.119381          0.136999
# Distance from Residence to Work            0.161831         -0.003759
# Service time                               0.048425         -0.062688
# Age                                       -0.078608         -0.000143
# Work load Average/day                     -0.123472         -0.170339
# Hit target                                 0.088943         -0.461249
# Disciplinary failure                      -0.545054          0.107880
# Education                                 -0.047357         -0.066774
# ...

# %%
corr["Absenteeism time in hours"].sort_values(ascending=False)
# Out:
# Absenteeism time in hours          1.000000
# Height                             0.144420
# Son                                0.113756
# Age                                0.065760
# Social drinker                     0.065067
# Transportation expense             0.027585
# Hit target                         0.026695
# Work load Average/day              0.024749
# Month of absence                   0.023779
# Service time                       0.019029
# Weight                             0.015789
# Seasons                           -0.005615
# Social smoker                     -0.008936
# Pet                               -0.028277
# Education                         -0.046235
# Body mass index                   -0.049719
# Distance from Residence to Work   -0.088363
# Disciplinary failure              -0.124248
# Day of the week                   -0.124361
# Reason for absence                -0.173116
# Name: Absenteeism time in hours, dtype: float64

# %% [markdown]
# #### No IDV has good correlation with DV

# %%
plt.figure(figsize=(20,18))
sns.heatmap(corr, annot=True)
plt.show()

# %%
## Finding outliers
plt.rcParams["figure.figsize"]=(15,5) ## to set the figsize
sns.boxplot(x="Age",y="Absenteeism time in hours", data=df)
plt.show()

# %%
## Finding outliers
plt.rcParams["figure.figsize"]=(15,5) ## to set the figsize
sns.boxplot(x="Son",y="Absenteeism time in hours", data=df)
plt.show()
