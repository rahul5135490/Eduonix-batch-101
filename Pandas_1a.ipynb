# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %% [markdown]
# # Pandas dataframe and indexing

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','basketball','golf'])
sports1
# Out:
# cricket       1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports1['football']
# Out:
# 2

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baseball','golf'])
sports2
# Out:
# cricket     11
# football     2
# baseball     3
# golf         4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball       NaN
# basketball     NaN
# cricket       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H '.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.422274  0.640864  0.590922  0.198158  0.662618
# B  0.916032  0.463874  0.743824  0.599980  0.222595
# C  0.788196  0.095657  0.326919  0.896680  0.000052
# D  0.182833  0.860047  0.094722  0.098253  0.577088
# E  0.535453  0.973886  0.075934  0.275423  0.829736
# F  0.227693  0.386062  0.298444  0.743171  0.744688
# G  0.590149  0.975159  0.808728  0.324082  0.385185
# H  0.294333  0.410653  0.652145  0.344941  0.970116

# %%
df1["Score1"]
# Out:
# A    0.422274
# B    0.916032
# C    0.788196
# D    0.182833
# E    0.535453
# F    0.227693
# G    0.590149
# H    0.294333
# Name: Score1, dtype: float64

# %%
df1[["Score1","Score2","Score3"]]
# Out:
#      Score1    Score2    Score3
# A  0.422274  0.640864  0.590922
# B  0.916032  0.463874  0.743824
# C  0.788196  0.095657  0.326919
# D  0.182833  0.860047  0.094722
# E  0.535453  0.973886  0.075934
# F  0.227693  0.386062  0.298444
# G  0.590149  0.975159  0.808728
# H  0.294333  0.410653  0.652145

# %%
df1['Score6']=df1['Score1']+df1['Score2']
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.422274  0.640864  0.590922  0.198158  0.662618  1.063138
# B  0.916032  0.463874  0.743824  0.599980  0.222595  1.379906
# C  0.788196  0.095657  0.326919  0.896680  0.000052  0.883853
# D  0.182833  0.860047  0.094722  0.098253  0.577088  1.042880
# E  0.535453  0.973886  0.075934  0.275423  0.829736  1.509339
# F  0.227693  0.386062  0.298444  0.743171  0.744688  0.613755
# G  0.590149  0.975159  0.808728  0.324082  0.385185  1.565308
# H  0.294333  0.410653  0.652145  0.344941  0.970116  0.704986

# %%
df2={'ID':['101','102','103','107','176'],'Name':['John','Mercy','Akash','Kavin','Lally'],'Profit':[20,54,56,87,123]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df["ID"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    107
# 4    176
# Name: ID, dtype: object

# %%
df[["ID","Name","Profit"]]
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df=df.drop("ID",axis=1)

# %%
df
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 3  Kavin      87
# 4  Lally     123

# %%
df.drop(3)
df
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 3  Kavin      87
# 4  Lally     123

# %% [markdown]
# # How to import Dataset using Pandas?

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("CardioGoodFitness-1.csv")

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baseball','golf'])
sports2
# Out:
# cricket     11
# football     2
# baseball     3
# golf         4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball       NaN
# basketball     NaN
# cricket       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H '.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.367813  0.205619  0.443785  0.899831  0.117724
# B  0.020425  0.331283  0.605770  0.386549  0.561771
# C  0.816008  0.830325  0.085237  0.153377  0.715381
# D  0.112274  0.434162  0.612627  0.200201  0.648184
# E  0.614941  0.618633  0.700293  0.024732  0.482794
# F  0.230984  0.732386  0.754425  0.786580  0.359150
# G  0.051710  0.145793  0.653176  0.623881  0.375451
# H  0.805576  0.627777  0.890781  0.903259  0.393377

# %%
df1["Score1"]
# Out:
# A    0.367813
# B    0.020425
# C    0.816008
# D    0.112274
# E    0.614941
# F    0.230984
# G    0.051710
# H    0.805576
# Name: Score1, dtype: float64

# %%
df1[["Score1","Score2","Score3"]]
# Out:
#      Score1    Score2    Score3
# A  0.367813  0.205619  0.443785
# B  0.020425  0.331283  0.605770
# C  0.816008  0.830325  0.085237
# D  0.112274  0.434162  0.612627
# E  0.614941  0.618633  0.700293
# F  0.230984  0.732386  0.754425
# G  0.051710  0.145793  0.653176
# H  0.805576  0.627777  0.890781

# %%
df1['Score6']=df1['Score1']+df1['Score2']
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.367813  0.205619  0.443785  0.899831  0.117724  0.573432
# B  0.020425  0.331283  0.605770  0.386549  0.561771  0.351707
# C  0.816008  0.830325  0.085237  0.153377  0.715381  1.646333
# D  0.112274  0.434162  0.612627  0.200201  0.648184  0.546436
# E  0.614941  0.618633  0.700293  0.024732  0.482794  1.233573
# F  0.230984  0.732386  0.754425  0.786580  0.359150  0.963370
# G  0.051710  0.145793  0.653176  0.623881  0.375451  0.197503
# H  0.805576  0.627777  0.890781  0.903259  0.393377  1.433353

# %%
df2={'ID':['101','102','103','107','176'],'Name':['John','Mercy','Akash','Kavin','Lally'],'Profit':[20,54,56,87,123]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df["ID"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    107
# 4    176
# Name: ID, dtype: object

# %%
df[["ID","Name","Profit"]]
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df=df.drop("ID",axis=1)

# %%
df.drop(3)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 4  Lally     123

# %%
df=pd.read_csv("tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
# 7                  Caldwell, Mr. Albert Francis    male  26.0      1      1
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 9                       Davies, Mr. John Samuel    male  21.0      2      0
#
#       Ticket     Fare Cabin Embarked
# 0     330911   7.8292   NaN        Q
# 1     363272   7.0000   NaN        S
# 2     240276   9.6875   NaN        Q
# 3     315154   8.6625   NaN        S
# 4    3101298  12.2875   NaN        S
# 5       7538   9.2250   NaN        S
# 6     330972   7.6292   NaN        Q
# 7     248738  29.0000   NaN        S
# 8       2657   7.2292   NaN        C
# 9  A/4 48871  24.1500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 172         1064         0       3
# 103          995         0       3
# 54           946         0       2
# 56           948         0       3
# 75           967         0       1
# 165         1057         1       3
# 179         1071         1       1
# 277         1169         0       2
# 36           928         1       3
# 13           905         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 172                           Dyker, Mr. Adolf Fredrik    male  23.0      1
# 103             Johansson Palmquist, Mr. Oskar Leander    male  26.0      0
# 54                   Mangiavacchi, Mr. Serafino Emilio    male   NaN      0
# 56                                     Cor, Mr. Bartol    male  35.0      0
# 75                                  Keeping, Mr. Edwin    male  32.5      0
# 165         Kink-Heilmann, Mrs. Anton (Luise Heilmann)  female  26.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 277                              Faunthorpe, Mr. Harry    male  40.0      1
# 36                                 Roth, Miss. Sarah A  female   NaN      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
#
#      Parch       Ticket      Fare Cabin Embarked
# 172      0       347072   13.9000   NaN        S
# 103      0       347070    7.7750   NaN        S
# 54       0  SC/A.3 2861   15.5792   NaN        C
# 56       0       349230    7.8958   NaN        S
# 75       0       113503  211.5000  C132        C
# 165      1       315153   22.0250   NaN        S
# 179      2     PC 17756   83.1583   E45        C
# 277      0         2926   26.0000   NaN        S
# 36       0       342712    8.0500   NaN        S
# 13       0        24065   26.0000   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.shape
# Out:
# (418, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# unique         NaN         NaN         NaN       363         NaN
# top            NaN         NaN         NaN  PC 17608         NaN
# freq           NaN         NaN         NaN         5         NaN
# mean     30.272590    0.447368    0.392344       NaN   35.627188
# std      14.181209    0.896760    0.981429       NaN   55.907576
# min       0.170000    0.000000    0.000000       NaN    0.000000
# 25%      21.000000    0.000000    0.000000       NaN    7.895800
# 50%      27.000000    0.000000    0.000000       NaN   14.454200
# 75%      39.000000    1.000000    0.000000       NaN   31.500000
# max      76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked
# count                91      418
# unique               76        3
# top     B57 B59 B63 B66        S
# freq                  3      270
# mean                NaN      NaN
# std                 NaN      NaN
# min                 NaN      NaN
# 25%                 NaN      NaN
# 50%                 NaN      NaN
# 75%                 NaN      NaN
# max                 NaN      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(x=df["Age"],color="red")
plt.title("Distribution of age",fontsize=20,color='blue')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(df["Age"])
plt.title("Distribution of Age")
plt.xlabel("Age")

plt.show()

# %%
df["Sex"].value_counts().plot(kind="barh",color='teal')
plt.title("Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
df["Pclass"].value_counts().plot(kind="barh",color='teal')
plt.title("Pclass Distribution")
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.show()

# %%
from matplotlib import cm
emb=df["Embarked"].value_counts()
keys=emb.keys().to_list()
counts=emb.to_list()
cs=cm.Set1([2,4,6,8])
plt.pie(x=counts,labels=keys,autopct='%1.1f%%',colors=cs)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x="Age",y="SibSp",data=df)
import numpy as np

# %%
df=pd.read_csv("CardioGoodFitness-1.csv")

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  103.194444
# std       0.958869   16506.684226   51.863605
# min       1.000000   29562.000000   21.000000
# 25%       3.000000   44058.750000   66.000000
# 50%       3.000000   50596.500000   94.000000
# 75%       4.000000   58668.000000  114.750000
# max       5.000000  104581.000000  360.000000
