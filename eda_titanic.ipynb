# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("titanic-training-data.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.distplot(df["Survived"],color="green")
plt.show()

# %%
sns.distplot(df["Pclass"],color="yellow")
plt.show()

# %%
sns.countplot(x="Cabin",hue="Embarked",data=df)
plt.show()

# %%
sns.countplot(x="Cabin",hue="Pclass",data=df)
plt.show()

# %%
sns.catplot(x="Pclass",y="Survived",kind="box", data=df)
plt.show()

# %%
sns.boxplot(x="Parch",y="Survived",data=df)
plt.show()

# %%
sns.catplot(x='Sex',y='Parch',data=df,kind='box')
plt.show()

# %%
sns.catplot(x='Survived',y='Parch',data=df,kind='box')
plt.show()

# %%
sns.boxplot(x="Pclass",y="Survived",data=df)
plt.show()

# %%
sns.violinplot(x="Parch",y="Survived",data=df)
plt.show()

# %%
sns.violinplot(x="Age",y="Survived",data=df)
plt.show()

# %%
sns.distplot(df["Age"])
plt.show()

# %%
sns.boxplot(x="Sex",y="Age",data=df)
plt.show()

# %%
sns.boxplot(x="Sex",y="Survived",data=df)
plt.show()

# %%
sns.violinplot(x="Sex",y="Survived",data=df)
plt.show()

# %%
sns.countplot(x="Sex",hue="Pclass",data=df)
plt.show()

# %%
sns.catplot(x="Survived",y="Ticket",kind="swarm",palette="Set2" ,data=df)
plt.show()

# %%
sns.relplot(x="Age",y="Survived",hue="Sex",data=df)
plt.show()

# %%
sns.relplot(x="Age",y="Survived",hue="Pclass",data=df)
plt.show()
